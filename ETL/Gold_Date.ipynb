# %%
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
# StatementMeta(, 86e88893-b920-4d31-a677-1a76de73c970, 19, Finished, Available, Finished)

# %%
# %%sql
# create table if not EXISTS ECommerce_Lakehouse.gold_date
# (
# BusinessDate Date,
# Business_Year int,
# Business_Month int,
# Business_Quarter int,
# Business_Week int
# )
# using DELTA
# PARTITIONED by (Business_Year)
# Out:
# StatementMeta(, 86e88893-b920-4d31-a677-1a76de73c970, 20, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
start_date='2015-01-01'
end_date='2030-12-31'

date_diff=spark.sql("select date_diff('{}','{}')".format(end_date,start_date)).first()[0]
# Out:
# StatementMeta(, 86e88893-b920-4d31-a677-1a76de73c970, 21, Finished, Available, Finished)

# %%
date_diff
# Out:
# StatementMeta(, 86e88893-b920-4d31-a677-1a76de73c970, 22, Finished, Available, Finished)
# 5843

# %%
ID_Data=spark.range(0,date_diff)
# Out:
# StatementMeta(, 86e88893-b920-4d31-a677-1a76de73c970, 23, Finished, Available, Finished)

# %%
date_data=ID_Data.selectExpr("date_add('{}',cast(id as int)) as BusinessDate".format(start_date))
# Out:
# StatementMeta(, 86e88893-b920-4d31-a677-1a76de73c970, 24, Finished, Available, Finished)

# %%
date_data.createOrReplaceTempView("ViewDate")
# Out:
# StatementMeta(, 86e88893-b920-4d31-a677-1a76de73c970, 25, Finished, Available, Finished)

# %%
# %%sql
#
# delete from ECommerce_Lakehouse.gold_date;
# Out:
# StatementMeta(, 86e88893-b920-4d31-a677-1a76de73c970, 26, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 1 fields>

# %%
# %%sql
# insert into ECommerce_Lakehouse.gold_date
# select *,
# Year(BusinessDate) as Business_Year,
# Month(BusinessDate) as Business_Month,
# Quarter(BusinessDate) as Business_Quarter,
# weekday(BusinessDate) as Business_Week
#  from ViewDate
# Out:
# StatementMeta(, 86e88893-b920-4d31-a677-1a76de73c970, 27, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# SELECT * FROM gold_date
# Out:
# StatementMeta(, 86e88893-b920-4d31-a677-1a76de73c970, 28, Finished, Available, Finished)
# <Spark SQL result set with 1000 rows and 5 fields>
