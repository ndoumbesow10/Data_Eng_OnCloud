# %%
from notebookutils import mssparkutils
# Out:
# StatementMeta(, 8b9dea87-6fc8-45be-8439-beee8b32cdb1, 3, Finished, Available, Finished)

# %%
mssparkutils.fs.mount("abfss://DataEngOnCloud@onelake.dfs.fabric.microsoft.com/ECommerce_Lakehouse.Lakehouse/Files","/Files")
# Out:
# StatementMeta(, 8b9dea87-6fc8-45be-8439-beee8b32cdb1, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, b7ab0eed-109e-47cd-8d2b-65bee7155310)
# True

# %%
mssparkutils.fs.getMountPath("/Files")
# Out:
# StatementMeta(, 8b9dea87-6fc8-45be-8439-beee8b32cdb1, 5, Finished, Available, Finished)
# '/synfs/notebook/8b9dea87-6fc8-45be-8439-beee8b32cdb1/Files'

# %%
check_files=mssparkutils.fs.ls(f"file://{mssparkutils.fs.getMountPath('/Files')}/ECommerce/")
# Out:
# StatementMeta(, 8b9dea87-6fc8-45be-8439-beee8b32cdb1, 6, Finished, Available, Finished)

# %%
for file in check_files:
    if file.path:
        mssparkutils.fs.mv(file.path,f"file://{mssparkutils.fs.getMountPath('/Files')}/Old_ECommerce/")
# Out:
# StatementMeta(, 8b9dea87-6fc8-45be-8439-beee8b32cdb1, 7, Finished, Available, Finished)
