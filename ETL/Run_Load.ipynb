# %%
from notebookutils import mssparkutils
# Out:
# StatementMeta(, e68e5ac3-0648-443e-90cd-6ed2333b6299, 3, Finished, Available, Finished)

# %%
mssparkutils.fs.mount("abfss://DataEngOnCloud@onelake.dfs.fabric.microsoft.com/ECommerce_Lakehouse.Lakehouse/Files","/Files")
# Out:
# StatementMeta(, e68e5ac3-0648-443e-90cd-6ed2333b6299, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 49d2d65e-cfb9-4361-966c-54d63c82589c)
# True

# %%
mssparkutils.fs.getMountPath("/Files")
# Out:
# StatementMeta(, e68e5ac3-0648-443e-90cd-6ed2333b6299, 5, Finished, Available, Finished)
# '/synfs/notebook/e68e5ac3-0648-443e-90cd-6ed2333b6299/Files'

# %%
check_files=mssparkutils.fs.ls(f"file://{mssparkutils.fs.getMountPath('/Files')}/ECommerce/")
# Out:
# StatementMeta(, e68e5ac3-0648-443e-90cd-6ed2333b6299, 8, Finished, Available, Finished)

# %%
if check_files:
    mssparkutils.notebook.run("Bronze_Sales")
    mssparkutils.notebook.run("Gold_Customer")
    mssparkutils.notebook.run("Gold_Date")
    mssparkutils.notebook.run("Gold_Product")
    mssparkutils.notebook.run("Gold_ShipMode")
    mssparkutils.notebook.run("Gold_OrderPriority")
    mssparkutils.notebook.run("Gold_OrderReturn")
    mssparkutils.notebook.run("Gold_Fact_Sale")
    mssparkutils.notebook.run("Archives_Files")
# Out:
# StatementMeta(, e68e5ac3-0648-443e-90cd-6ed2333b6299, 9, Finished, Available, Finished)
