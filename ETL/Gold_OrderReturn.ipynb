# %%
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
# StatementMeta(, 59442326-c1ef-4213-bbee-685354c3aa60, 3, Finished, Available, Finished)

# %%
# %%sql
#
# create table if not exists ECommerce_Lakehouse.Gold_OrderReturn
# (
#
# Order_ID  string,
# Return string,
# Order_Year int,
# Order_Month int,
# Created_TS TIMESTAMP,
# Modified_TS TIMESTAMP
#
# )
# using delta
# partitioned by(Order_Year,Order_Month)
# Out:
# StatementMeta(, 59442326-c1ef-4213-bbee-685354c3aa60, 4, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
Max_Date=spark.sql("select coalesce(max(Modified_TS),'1900-01-01') from ECommerce_Lakehouse.gold_orderreturn").first()[0]
# Out:
# StatementMeta(, 59442326-c1ef-4213-bbee-685354c3aa60, 5, Finished, Available, Finished)

# %%
Max_Date
# Out:
# StatementMeta(, 59442326-c1ef-4213-bbee-685354c3aa60, 6, Finished, Available, Finished)
# '1900-01-01'

# %%
df=spark.sql("""select Order_ID  ,
Return ,
Order_Year, 
Order_Month ,
Created_TS ,
Modified_TS 
from ECommerce_Lakehouse.bronze_sales where Return="Yes" and Modified_TS>'{}'""".format(Max_Date))
# Out:
# StatementMeta(, 59442326-c1ef-4213-bbee-685354c3aa60, 7, Finished, Available, Finished)

# %%
df.createOrReplaceTempView("ViewReturn")
# Out:
# StatementMeta(, 59442326-c1ef-4213-bbee-685354c3aa60, 8, Finished, Available, Finished)

# %%
# %%sql
# insert into ECommerce_Lakehouse.gold_orderreturn
# select * from ViewReturn
# Out:
# StatementMeta(, 59442326-c1ef-4213-bbee-685354c3aa60, 9, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>
