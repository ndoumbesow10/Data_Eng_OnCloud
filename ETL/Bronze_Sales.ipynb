# %%
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.types import *
import pandas as pd
# Out:
# StatementMeta(, bd98d6e1-2119-433f-842c-b3169b64df07, 3, Finished, Available, Finished)

# %%
df_sales= pd.read_excel("abfss://DataEngOnCloud@onelake.dfs.fabric.microsoft.com/ECommerce_Lakehouse.Lakehouse/Files/ECommerce/Sales*.xlsx",sheet_name= "Sales")
# Out:
# StatementMeta(, bd98d6e1-2119-433f-842c-b3169b64df07, 5, Finished, Available, Finished)

# %%
df1=spark.createDataFrame(df_sales)
# Out:
# StatementMeta(, bd98d6e1-2119-433f-842c-b3169b64df07, 6, Finished, Available, Finished)

# %%
display(df1.head(10))
# Out:
# StatementMeta(, bd98d6e1-2119-433f-842c-b3169b64df07, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, b3256a73-ee07-45be-8da1-a25141282d4a)

# %%
df_Returns= pd.read_excel("abfss://DataEngOnCloud@onelake.dfs.fabric.microsoft.com/ECommerce_Lakehouse.Lakehouse/Files/ECommerce/Sales*.xlsx",sheet_name= "Returns")
# Out:
# StatementMeta(, bd98d6e1-2119-433f-842c-b3169b64df07, 9, Finished, Available, Finished)

# %%
df2=spark.createDataFrame(df_Returns)
# Out:
# StatementMeta(, bd98d6e1-2119-433f-842c-b3169b64df07, 10, Finished, Available, Finished)

# %%
display(df2.head(10))
# Out:
# StatementMeta(, bd98d6e1-2119-433f-842c-b3169b64df07, 11, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 0668396f-42d6-4460-b575-9ecfd8b8a9bd)

# %%
df_final=df1.join(df2,df1.Order_ID==df2.Order_ID,how="left").drop(df2.Order_ID,df2.Customer_Name,df2.Sales_Amount)
# Out:
# StatementMeta(, bd98d6e1-2119-433f-842c-b3169b64df07, 12, Finished, Available, Finished)

# %%
df_mod=df_final.withColumns({"Order_Year": year("Order_Date"), \
                "Order_Month": month("Order_Date"), \
                "Created_TS": current_timestamp(),\
                "Modified_TS": current_timestamp(),\
                })
# Out:
# StatementMeta(, bd98d6e1-2119-433f-842c-b3169b64df07, 13, Finished, Available, Finished)

# %%
df_mod.createOrReplaceTempView("ViewSales")
# Out:
# StatementMeta(, bd98d6e1-2119-433f-842c-b3169b64df07, 14, Finished, Available, Finished)

# %%
# %%sql
# create table if not exists ECommerce_Lakehouse.Bronze_Sales
# (
#     Order_ID	string,
#     Order_Date	Date,
#     Shipping_Date	date,
#     Aging	int,
#     Ship_Mode	string,
#     Product_Category	string,
#     Product	 string,
#     Sales 	float,
#     Quantity	float,
#     Discount	 float,
#     Profit 	 float,
#     Shipping_Cost 	float,
#     Order_Priority	string,
#     Customer_ID	string,
#     Customer_Name	string,
#     Segment	string,
#     City	string,
#     State	string,
#     Country	string,
#     Region string,
# 	Return string,
#     Order_Year int,
#     Order_Month int,
#     Created_TS  TIMESTAMP,
#     Modified_TS  TIMESTAMP
# )
# using DELTA
# PARTITIONED by(Order_Year,Order_Month)
# Out:
# StatementMeta(, bd98d6e1-2119-433f-842c-b3169b64df07, 15, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# Merge into ECommerce_Lakehouse.Bronze_Sales as BS
# using ViewSales as VS
# on  BS.Order_Year=VS.Order_Year and BS.Order_Month=VS.Order_Month and BS.Order_ID=VS.Order_ID
# when matched then
# update SET
# BS.Order_Date	=	VS.Order_Date	,
# BS.Shipping_Date	=	VS.Shipping_Date	,
# BS.Aging	=	VS.Aging	,
# BS.Ship_Mode	=	VS.Ship_Mode	,
# BS.Product_Category	=	VS.Product_Category	,
# BS.Product	=	VS.Product	,
# BS.Sales 	=	VS.Sales 	,
# BS.Quantity	=	VS.Quantity	,
# BS.Discount	=	VS.Discount	,
# BS.Profit 	=	VS.Profit 	,
# BS.Shipping_Cost 	=	VS.Shipping_Cost 	,
# BS.Order_Priority	=	VS.Order_Priority	,
# BS.Customer_ID	=	VS.Customer_ID	,
# BS.Customer_Name	=	VS.Customer_Name	,
# BS.Segment	=	VS.Segment	,
# BS.City	=	VS.City	,
# BS.State	=	VS.State	,
# BS.Country	=	VS.Country	,
# BS.Region  	=	VS.Region  	,
# BS.Return  	=	VS.Return  	,
# BS.Modified_TS	=	VS.Modified_TS
#
# when not matched then
# INSERT
# (
# BS.Order_ID,
# BS.Order_Date	,
# BS.Shipping_Date	,
# BS.Aging	,
# BS.Ship_Mode	,
# BS.Product_Category	,
# BS.Product	,
# BS.Sales 	,
# BS.Quantity	,
# BS.Discount	,
# BS.Profit 	,
# BS.Shipping_Cost 	,
# BS.Order_Priority	,
# BS.Customer_ID	,
# BS.Customer_Name	,
# BS.Segment	,
# BS.City	,
# BS.State	,
# BS.Country	,
# BS.Region  	,
# BS.Return,
# BS.Order_Year  	,
# BS.Order_Month  	,
# BS.Created_TS   	,
# BS.Modified_TS
# )
# values
# (
# VS.Order_ID,
# VS.Order_Date	,
# VS.Shipping_Date	,
# VS.Aging	,
# VS.Ship_Mode	,
# VS.Product_Category	,
# VS.Product	,
# VS.Sales 	,
# VS.Quantity	,
# VS.Discount	,
# VS.Profit 	,
# VS.Shipping_Cost 	,
# VS.Order_Priority	,
# VS.Customer_ID	,
# VS.Customer_Name	,
# VS.Segment	,
# VS.City	,
# VS.State	,
# VS.Country	,
# VS.Region  	,
# VS.Return,
# VS.Order_Year  	,
# VS.Order_Month  	,
# VS.Created_TS   	,
# VS.Modified_TS
#
# )
# Out:
# StatementMeta(, bd98d6e1-2119-433f-842c-b3169b64df07, 16, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 4 fields>

# %%
# %%sql
# Select * from ECommerce_Lakehouse.Bronze_Sales
# Out:
# StatementMeta(, bd98d6e1-2119-433f-842c-b3169b64df07, 17, Finished, Available, Finished)
# <Spark SQL result set with 1000 rows and 25 fields>
